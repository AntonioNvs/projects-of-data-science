# %% [markdown]
# <a href="https://colab.research.google.com/github/AntonioNvs/projects-of-data-science/blob/main/Imers%C3%A3o-Dados-Alura-3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Primeiro Dia

# %%
import pandas as pd
import matplotlib.pyplot as plt

url_dados = "https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true"

dados = pd.read_csv(url_dados, compression='zip')
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
# Retorna os valores únicos da coluna
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
len(dados['droga'].unique())
# Out:
# 3289

# %%
dados['tratamento'].value_counts(normalize=True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['dose'].value_counts(normalize=True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['tratamento'].value_counts().plot.pie()
plt.title('Hi')
# Out:
# Text(0.5, 1.0, 'Hi')

# %%
dados['tempo'].value_counts().plot.bar()

# %%
dados_filtrados = dados[dados['g-0'] > 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %%
columns = dados.columns

newColumns = {}
for i in columns:
  newColumns[i] = i.replace('-', '')

dados.rename(columns=newColumns, inplace=True)
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# # Segundo dia

# %%
dados.rename(columns={'droga': 'composto'}, inplace=True)
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
cod_compostos = dados['composto'].value_counts().index[:5]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(font_scale=1.2)
plt.figure(figsize=(8, 6))

dados_principais_compostos = dados.query('composto in @cod_compostos')

ax = sns.countplot(x = 'composto', data=dados_principais_compostos, order=dados_principais_compostos['composto'].value_counts().index)

ax.set_xlabel('Compostos')
ax.set_ylabel('Contagem')
ax.set_title('Top 5 Compostos')

plt.show()

# %%
plt.figure(figsize=(16, 10))

dados.hist(column=['g0', 'g19'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4a7ee93ed0>,
# ...
#       dtype=object)

# %%
dados.loc[:, 'g0':'g771']
# Out:
#            g0      g1      g2      g3  ...    g768    g769    g770    g771
# 0      1.0620  0.5577 -0.2479 -0.6208  ...  0.3008  1.6490  0.2968 -0.0224
# 1      0.0743  0.4087  0.2991  0.0604  ... -0.1626 -0.3340 -0.3289 -0.2718
# 2      0.6280  0.5817  1.5540 -0.0764  ...  0.5797  0.3143  0.8133  0.7923
# 3     -0.5138 -0.2491 -0.2656  0.5288  ...  0.1996  0.4374  0.1588 -0.0343
# 4     -0.3254 -0.4009  0.9700  0.6919  ... -1.0020 -0.7534  0.5000 -0.6269
# ...       ...     ...     ...     ...  ...     ...     ...     ...     ...
# 23809  0.1394 -0.0636 -0.1112 -0.5080  ...  0.7221  0.5099 -0.1423  0.3806
# 23810 -1.3260  0.3478 -0.3743  0.9905  ...  0.5247  0.5438 -0.1875 -0.4751
# 23811  0.3942  0.3756  0.3109 -0.7389  ...  0.9778  0.2326 -0.6191  0.3603
# 23812  0.6660  0.2324  0.4392  0.2044  ...  0.1794  0.3109 -0.3491 -0.4741
# 23813 -0.8598  1.0240 -0.1361  0.7952  ...  1.5410  0.3633 -3.1970  2.2190
#
# [23814 rows x 772 columns]

# %%
dados.loc[:, 'g0':'g771'].describe().T['mean'].hist(bins = 50)

# %%
dados.loc[:, 'c0':'c99'].describe().T['mean'].hist(bins = 50)

# %%
sns.boxplot(x = 'g0', data=dados)

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(y = 'g0', x = 'tempo', data=dados)

# %% [markdown]
# # Terceiro Dia

# %%
pd.crosstab(dados['dose'], dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
sns.scatterplot(x='g0', y = 'g3', data=dados)

# %%
sns.lmplot(data=dados, x='g0', y='g8', line_kws={'color': 'red'}, col='tratamento', row='tempo')

# %%
# Relação entre as colunas
import numpy as np

corr = dados.loc[:, 'g0':'g50'].corr()

mask = np.triu(np.ones_like(corr, dtype=bool))

f, ax = plt.subplots(figsize=(11, 9))

cmap = sns.diverging_palette(230, 30, as_cmap=True)

sns.heatmap(corr, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={'shrink': .5})

# %%
corr_celular = dados.loc[:, 'c0':'c50'].corr()

mask = np.triu(np.ones_like(corr_celular, dtype=bool))

f, ax = plt.subplots(figsize=(11, 9))

cmap = sns.diverging_palette(230, 30, as_cmap=True)

sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={'shrink': .5})

# %% [markdown]
# # Quarto Dia

# %%
dados_resultado = pd.read_csv('https://raw.githubusercontent.com/alura-cursos/imersao-dados-desafio-final/main/Dados/dados_resultados.csv')
dados_resultado.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultado['acat_inhibitor'].unique()
# Out:
# array([0, 1])

# %%
contagem_moa = dados_resultado.select_dtypes('int64').sum().sort_values(ascending=False)

classes = {}

for key, value in contagem_moa.to_dict().items():
  typeClass = key.split('_')[-1]

  try:
    classes[typeClass] += value
  except:
    classes[typeClass] = value

sorted(classes.items(), key=lambda item: item[1], reverse=True)
# Out:
# [('inhibitor', 9693),
#  ('antagonist', 3449),
#  ('agonist', 2330),
#  ('blocker', 323),
#  ('agent', 150),
#  ('activator', 115),
#  ('local', 80),
#  ('anti-inflammatory', 73),
#  ('antioxidant', 73),
#  ('immunosuppressant', 73),
#  ('medium', 56),
#  ('sensitizer', 51),
#  ('stimulant', 49),
#  ('antibiotic', 43),
#  ('antifolate', 36),
#  ('antiprotozoal', 36),
#  ('secretagogue', 30),
#  ('donor', 26),
#  ('b', 26),
#  ('antiviral', 23),
#  ('antimalarial', 18),
#  ('scavenger', 18),
#  ('antifungal', 13),
#  ('analgesic', 12),
#  ('antihistamine', 12),
#  ('anticonvulsant', 12),
#  ('laxative', 6),
#  ('steroid', 6),
#  ('antiarrhythmic', 6),
#  ('diuretic', 6)]

# %%
dados_resultado['n_moa'] = dados_resultado.drop('id', axis=1).sum(axis=1)

# %%
dados_resultado['ativo_moa'] = (dados_resultado['n_moa'] != 0)

# %%
dados_combinados = pd.merge(dados, dados_resultado[['id', 'n_moa', 'ativo_moa']], on='id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...     c98     c99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
dados_combinados.query('tratamento == "com_controle"')
# Out:
#                  id    tratamento  tempo dose  ...     c98     c99  n_moa  ativo_moa
# 25     id_0054388ec  com_controle     48   D1  ...  0.8976  1.0050      0      False
# 38     id_0079af0fb  com_controle     24   D1  ...  0.6498 -1.4820      0      False
# 40     id_007bfbb91  com_controle     24   D2  ...  0.8543  0.9180      0      False
# 47     id_008a986b7  com_controle     48   D2  ... -0.9245 -0.9367      0      False
# 63     id_009d8340f  com_controle     24   D2  ... -0.4326  0.9364      0      False
# ...             ...           ...    ...  ...  ...     ...     ...    ...        ...
# 23729  id_ff1f9e5fc  com_controle     24   D1  ... -0.2422  0.0457      0      False
# 23747  id_ff469c482  com_controle     72   D1  ... -0.0742 -0.6777      0      False
# 23768  id_ff89331ca  com_controle     72   D2  ... -0.1748 -0.3626      0      False
# 23793  id_ffd26f361  com_controle     48   D2  ... -0.5272  0.7082      0      False
# ...

# %%
dados_combinados['eh_controle'] = (dados_combinados['tratamento'] == 'com_controle')
dados_combinados['eh_24'] = (dados_combinados['tempo'] == 24)
dados_combinados['eh_48'] = (dados_combinados['tempo'] == 48)
dados_combinados['eh_72'] = (dados_combinados['tempo'] == 72)
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ... eh_controle  eh_24  eh_48  eh_72
# 0  id_000644bb2  com_droga     24   D1  ...       False   True  False  False
# 1  id_000779bfc  com_droga     72   D1  ...       False  False  False   True
# 2  id_000a6266a  com_droga     48   D1  ...       False  False   True  False
# 3  id_0015fd391  com_droga     48   D1  ...       False  False   True  False
# 4  id_001626bd3  com_droga     72   D2  ...       False  False  False   True
#
# [5 rows x 883 columns]

# %%
dados_combinados.query('tratamento == "com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
composto_principal = dados_combinados['composto'].value_counts().index[:5]
plt.figure(figsize=(10, 8))
sns.boxplot(data = dados_combinados.query('composto in @composto_principal'), y = 'g0', x = 'composto', hue='ativo_moa')

# %% [markdown]
# # Quinto Dia

# %%
dados_resultado.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
resultados_das_classificacoes = {}
random_state = 20202

# %%
from sklearn.model_selection import train_test_split

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, random_state=random_state)

# %%
from sklearn.linear_model import LogisticRegression

modelo_rlogistica = LogisticRegression(max_iter=1000)
modelo_rlogistica.fit(x_treino, y_treino)
resultados_das_classificacoes['LogisticRegression'] = modelo_rlogistica.score(x_teste, y_teste)

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score

modelo_dummy = DummyClassifier('most_frequent')
modelo_dummy.fit(x_treino, y_treino)
previsao_dummy = modelo_dummy.predict(x_teste)
resultados_das_classificacoes['DummyClassifier'] = accuracy_score(y_teste, previsao_dummy)

# %%
from sklearn.tree import DecisionTreeClassifier

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, random_state=random_state)

modelo_arvore = DecisionTreeClassifier()
modelo_arvore.fit(x_treino, y_treino)
resultados_das_classificacoes['DecisionTreeClassifier'] = modelo_arvore.score(x_teste, y_teste)

# %%
# from sklearn import tree

# fig, ax = plt.subplots(figsize=(15, 10), facecolor='k')

# tree.plot_tree(modelo_arvore,
#                ax=ax,
#                fontsize=10,
#                rounded=True,
#                filled=True,
#                feature_names=x_treino.columns,
#                class_names=['Não Ativado', 'Ativado'])

plt.show()

# %%
# from sklearn.tree import DecisionTreeClassifier

# x = dados_combinados.select_dtypes('float64')
# y = dados_combinados['ativo_moa']

# x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, random_state=20202)

# # Testando diversas profundidades

# teste = []
# treino = []
# for i in range(1, 15):
#   modelo_arvore = DecisionTreeClassifier(max_depth = i)
#   modelo_arvore.fit(x_treino, y_treino)
#   teste.append(round(modelo_arvore.score(x_teste, y_teste), 3))
#   treino.append(round(modelo_arvore.score(x_treino, y_treino), 3))

# %%
# sns.lineplot(x=range(1, 15), y = teste, label='teste')
# sns.lineplot(x=range(1, 15), y = treino, label='treino')

# %%
from sklearn.ensemble import RandomForestClassifier


x = dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'composto'], axis=1)
x = pd.get_dummies(x, columns=['tratamento', 'dose', 'tempo'])
y = dados_combinados['ativo_moa']

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, random_state=random_state)

modelo_randomforest = RandomForestClassifier()
modelo_randomforest.fit(x_treino, y_treino)
resultados_das_classificacoes['RandomForestClassifier'] = modelo_randomforest.score(x_teste, y_teste)

# %%
resultados_das_classificacoes
# Out:
# {'DecisionTreeClassifier': 0.5836657568759185,
#  'DummyClassifier': 0.6191475960529078,
#  'LogisticRegression': 0.6340541675414655,
#  'RandomForestClassifier': 0.7048078941843376}

# %%
tipos = resultados_das_classificacoes.keys()
resultados = resultados_das_classificacoes.values()

plt.figure(figsize=(12, 6))
plt.bar(tipos, resultados)
plt.xlabel('Modelos')
plt.ylabel('Acurácia em %')
plt.title('Comparação da acurácia entre os modelos')
plt.show()
